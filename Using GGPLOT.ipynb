# %%
import pandas as pd
import numpy as np
import scipy as sp
import plotly.plotly as py

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/iqbalhabibie/plotly/master/datasets/tobacco.csv')

# %%
list(data)
# Out:
# ['Region', 'Alcohol', 'Tobacco']

# %%
print(data)
# Out:
#               Region  Alcohol  Tobacco
# 0              North     6.47     4.03
# 1          Yorkshire     6.13     3.76
# 2          Northeast     6.19     3.77
# 3      East Midlands     4.89     3.34
# 4      West Midlands     5.63     3.47
# 5        East Anglia     4.52     2.92
# 6          Southeast     5.89     3.20
# 7          Southwest     4.79     2.71
# 8              Wales     5.27     3.53
# 9           Scotland     6.08     4.51
# 10  Northern Ireland     4.02     4.56

# %%
#create  a data frame
df = data.ix[-5:,['Alcohol','Tobacco']]

# %%
#plot
df.plot(kind = 'bar')

plt.show()

# %%
#for ggplot
plt.style.use('ggplot')

df.plot()

plt.show()
